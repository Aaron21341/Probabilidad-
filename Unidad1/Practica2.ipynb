# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron21341/Probabilidad-/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# probabilidad y estadistica

## **Unidad 1**

### Practica 2: **Maximo, minimo, dispercion de datos **

### Docente: Jose Gabriel Rodriguez Rivas

### Alumno: Aaron Antonio Contreras Herrera

# %%
import random
import matplotlib.pyplot as plt

from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio1 = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio1)

print(fabrica1)
# Out:
# [53.51, 66.93, 71.98, 68.19, 83.69, 60.11, 78.52, 74.77, 94.51, 81.02, 68.55, 54.9, 83.14, 70.52, 51.95, 89.43, 98.46, 87.86, 79.24, 66.83, 81.03, 64.45, 55.09, 98.63, 52.22, 96.16, 60.69, 97.57, 54.37, 94.78, 63.58, 54.45, 81.27, 98.53, 80.89, 67.09, 96.98, 60.95, 82.44, 59.55, 63.8, 67.09, 71.86, 64.24, 62.8, 92.01, 67.25, 75.91, 67.97, 54.28, 99.26, 72.35, 97.21, 69.79, 75.9, 66.91, 82.11, 98.18, 97.44, 79.91, 93.16, 96.95, 72.66, 59.13, 99.77, 90.53, 60.41, 72.35, 92.04, 83.34, 69.29, 71.26, 56.04, 71.67, 99.3, 88.87, 53.29, 80.32, 70.0, 93.58, 54.98, 97.53, 58.74, 62.56, 69.0, 91.97, 68.29, 75.14, 76.06, 51.28, 68.53, 62.42, 50.73, 53.08, 63.12, 89.72, 81.85, 86.9, 55.88, 63.38]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round(random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio1)

print(fabrica2)
# Out:
# [63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38, 63.38]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estatica descriptiva de la fabrica 1 \n","media =", media1,"\n mediana =",mediana1,"\n moda =",moda1,"\n maximo =",maximo1,"\n minimo 0",minimo1,"\n rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estatica descriptiva de la fabrica 1
#  media = 74.6622
#  mediana = 71.92
#  moda = 67.09
#  maximo = 99.77
#  minimo 0 50.73
#  rango = 49.04
# 14.882262751546238

# %%
maximo2= max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estatica descriptiva de la fabrica 2 \n","media =",media2,"\n mediana =",mediana2,"\n moda =",moda2,"\n maximo =", maximo2,"\n minimo ", minimo2,"\n rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estatica descriptiva de la fabrica 2
#  media = 63.38
#  mediana = 63.38
#  moda = 63.38
#  maximo = 63.38
#  minimo  63.38
#  rango = 0.0
# 0.0

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")

plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(desviacion_estandar_fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")

plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fabrica 2')
plt.legend()
plt.show()

# %%
import seaborn as sns

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10);
