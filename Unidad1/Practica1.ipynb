# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron21341/Probabilidad-/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # probabilidad y estadistica
#
# # **Unidad 1**
#
# ## Practica 1: **Estadistica descriptiva e histogramas**
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Aaron Antonio Contreras Herrera

# %%
from statistics import *
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
type(grupoa)
promedio = sum(grupoa) / len(grupoa)
print(promedio)
promedio2 = mean(grupoa)
print(promedio2)
mediana = median(grupoa)
print(mediana)
moda = mode(grupoa)
print(moda)
# ejemplo 2
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.5, 15.19, 17.20]
print(tiempos100mts)
print("El tiempo promedio de los corredores es=>", mean(tiempos100mts) )
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es=>", mediana)
moda = mode(tiempos100mts)
print("La moda de los tiempos es=>", moda)
multimodas = multimode(tiempos100mts)
print("La moda de los tiempos es=>", multimodas)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.5, 15.19, 17.2]
# El tiempo promedio de los corredores es=> 17.316
# La media de los tiempos de los corredores es=> 17.2
# La moda de los tiempos es=> 17.2
# La moda de los tiempos es=> [17.2]

# %%
# ejemplo 3 : Histogramas de 2 grupos

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [78.77, 97.95, 84.82, 98.67, 78.96, 74.85, 54.04, 57.08, 93.6, 75.83, 94.95, 76.15, 69.81, 55.31, 79.29, 86.95, 91.09, 72.98, 80.86, 59.19, 93.27, 52.66, 95.81, 84.01, 80.53, 69.89, 69.57, 77.9, 73.02, 51.95, 53.18, 88.66, 90.98, 68.37, 89.07, 78.94, 69.23, 62.33, 66.85, 96.6, 92.62, 83.26, 81.63, 79.34, 72.9, 90.11, 88.44, 96.04, 92.19, 84.68, 85.89, 76.47, 81.13, 92.77, 83.1, 72.24, 92.53, 87.32, 71.63, 60.37, 55.0, 89.19, 98.68, 56.23, 60.56, 77.82, 81.14, 69.4, 76.98, 80.9, 64.56, 88.91, 50.4, 63.82, 52.64, 50.29, 83.32, 75.79, 66.34, 77.92, 89.36, 75.71, 81.6, 78.51, 55.33, 66.3, 83.92, 79.72, 94.95, 66.41, 85.63, 93.75, 83.18, 61.9, 69.66, 76.1, 58.72, 89.9, 86.39, 50.99]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [99.94, 85.94, 77.07, 67.22, 71.32, 85.11, 52.99, 51.37, 71.88, 94.42, 96.55, 87.32, 51.82, 81.46, 69.01, 58.01, 53.29, 83.96, 93.06, 76.35, 92.67, 50.88, 77.55, 79.3, 68.05, 76.77, 79.98, 85.94, 78.65, 98.44, 96.61, 99.2, 93.54, 65.89, 62.81, 60.05, 86.61, 84.65, 99.7, 59.74, 79.45, 81.26, 94.36, 70.69, 82.99, 79.15, 64.18, 85.7, 78.7, 60.77, 66.75, 65.64, 78.66, 55.23, 98.97, 61.77, 62.55, 87.92, 87.2, 86.96, 90.03, 72.34, 57.83, 50.83, 84.59, 94.61, 78.16, 62.07, 89.02, 70.37, 64.98, 83.75, 91.99, 80.52, 73.72, 64.27, 71.82, 80.28, 69.06, 62.17, 51.29, 58.98, 75.4, 76.5, 73.27, 57.57, 64.3, 63.4, 83.85, 69.89, 52.9, 85.85, 73.04, 58.55, 75.45, 86.52, 58.08, 90.48, 85.46, 88.98]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media = mean (fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)
print("valores de la fabrica 1")
print("la media es =", media)
print("la mediana es =",mediana)
print("la moda es =", moda )
# Out:
# valores de la fabrica 1
# la media es = 76.8655
# la mediana es = 78.85499999999999
# la moda es = 94.95

# %%
media = mean (fabrica2)
mediana = median(fabrica2)
moda= mode(fabrica2)
print("valores de la fabrica 2")
print("la media es =", media)
print("la mediana es =",mediana)
print("la moda es =", moda )
# Out:
# valores de la fabrica 2
# la media es = 75.5619
# la mediana es = 76.91999999999999
# la moda es = 85.94

# %%
# generar 2 subplot de 1 reglon
fig, (ax1,ax2) = plt.subplots(nrows =1, ncols=2)
